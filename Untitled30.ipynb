# %% [markdown]
# <a href="https://colab.research.google.com/github/carlosks/carlosks/blob/main/Untitled30.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# lendo a base de dados
# Since the file is a CSV, use pd.read_csv instead of pd.read_excel
dataset = pd.read_excel("Extrato conta_092024.xlsx")

# %%
dataset.head()
# Out:
#          Data         Lançamento                       Detalhes N° documento  \
# 0  30/08/2024     Saldo Anterior
# 1  02/09/2024  Compra com Cartão   31/08 08:38 POSTO BELA VISTA       131100
# 2  02/09/2024  Compra com Cartão   01/09 11:35 POSTO BELA VISTA       241758
# 3  02/09/2024  Compra com Cartão   01/09 12:17 ZAFFARI P. ALVES       344276
# 4  02/09/2024  Compra com Cartão  01/09 16:59 TARTONI RISTORANT       661180
#
#      Valor Tipo Lançamento
# 0     0,00
# 1   -92,02           Saída
# 2   -90,90           Saída
# 3  -256,80           Saída
# 4  -231,00           Saída

# %%
# tamanho do dataset - linhas e colunas
dataset.shape
# Out:
# (300, 6)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Data             300 non-null    object
#  1   Lançamento       300 non-null    object
#  2   Detalhes         297 non-null    object
#  3   N° documento     300 non-null    object
#  4   Valor            300 non-null    object
#  5   Tipo Lançamento  300 non-null    object
# dtypes: object(6)
# memory usage: 14.2+ KB

# %%
# análise estatística
dataset.describe().round(2)
# Out:
#               Data         Lançamento     Detalhes N° documento Valor  \
# count          300                300          297          300   300
# unique          23                 28          248          253   242
# top     30/09/2024  Compra com Cartão  Rende Facil         9903  0,00
# freq            41                159           23           23    22
#
#        Tipo Lançamento
# count              300
# unique               3
# top              Saída
# freq               248

# %%
grupo_categoria_Detalhes = dataset.groupby(["Categoria", "Detalhes"]).sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-3042ec8a950d> in <cell line: 1>()
# ----> 1 grupo_categoria_Detalhes = dataset.groupby(["Categoria", "Detalhes"]).sum()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9181             raise TypeError("You have to supply one of 'by' and 'level'")
#    9182
# -> 9183         return DataFrameGroupBy(
#    9184             obj=self,
#    9185             keys=by,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1327
#    1328         if grouper is None:
# -> 1329             grouper, exclusions, obj = get_grouper(
#    1330                 obj,
# ...

# %%
print(dataset.columns)
# Out:
# Index(['Data', 'Lançamento', 'Detalhes', 'N° documento', 'Valor',
#        'Tipo Lançamento'],
#       dtype='object')
