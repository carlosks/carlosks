# %% [markdown]
# <a href="https://colab.research.google.com/github/carlosks/carlosks/blob/main/Untitled11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

import numpy as np

import matplotlib.pyplot as plt



# Definição das características dos deputados

class Deputado:

    def __init__(self, ficha_limpa, educacao, experiencia, transparencia, popularidade):

        self.ficha_limpa = ficha_limpa

        self.educacao = educacao

        self.experiencia = experiencia

        self.transparencia = transparencia

        self.popularidade = popularidade



    def __repr__(self):

        return (f"Deputado(Ficha Limpa: {self.ficha_limpa}, Educação: {self.educacao}, "

                f"Experiência: {self.experiencia}, Transparência: {self.transparencia}, "

                f"Popularidade: {self.popularidade})")



# Parâmetros do algoritmo genético

population_size = 513

num_generations = 40  # Aumentando o número de gerações para maior garantia de convergência

mutation_rate = 0.01



# Função de aptidão

def calculate_fitness(deputado):

    fitness = (deputado.ficha_limpa * 5 +

               deputado.educacao * 2 +

               deputado.experiencia +

               deputado.transparencia * 3 +

               deputado.popularidade * 2)

    return fitness



# Geração de uma população inicial aleatória

def generate_random_population(population_size):

    population = []

    for _ in range(population_size):

        ficha_limpa = random.randint(0, 1)

        educacao = random.randint(0, 5)

        experiencia = random.randint(0, 25)

        transparencia = random.randint(0, 5)

        popularidade = random.randint(0, 100)

        deputado = Deputado(ficha_limpa, educacao, experiencia, transparencia, popularidade)

        population.append(deputado)

    return population



# Cruzamento de dois deputados

def crossover(parent1, parent2):

    crossover_point = random.randint(1, 4)

    child1_attrs = list(parent1.__dict__.values())[:crossover_point] + list(parent2.__dict__.values())[crossover_point:]

    child2_attrs = list(parent2.__dict__.values())[:crossover_point] + list(parent1.__dict__.values())[crossover_point:]

    return Deputado(*child1_attrs), Deputado(*child2_attrs)



# Mutação de um deputado

def mutate(deputado):

    attrs = list(deputado.__dict__.keys())

    attr_to_mutate = random.choice(attrs)

    if attr_to_mutate == 'ficha_limpa':

        deputado.ficha_limpa = 1 - deputado.ficha_limpa

    else:

        if attr_to_mutate == 'educacao':

            setattr(deputado, attr_to_mutate, random.randint(0, 5))

        elif attr_to_mutate == 'experiencia':

            setattr(deputado, attr_to_mutate, random.randint(0, 25))

        elif attr_to_mutate == 'transparencia':

            setattr(deputado, attr_to_mutate, random.randint(0, 5))

        elif attr_to_mutate == 'popularidade':

            setattr(deputado, attr_to_mutate, random.randint(0, 100))

    return deputado



# Função para plotar a evolução da aptidão

def plot_evolution(best_fitness_values, mean_fitness_values, generation_reached_max_fitness):

    generations = list(range(len(best_fitness_values)))

    plt.figure(figsize=(10, 6))

    plt.plot(generations, best_fitness_values, label='Melhor Aptidão')

    plt.plot(generations, mean_fitness_values, label='Aptidão Média')

    if generation_reached_max_fitness is not None:

        plt.axvline(x=generation_reached_max_fitness, color='red', linestyle='--', label='Aptidão Máxima Atingida')

    plt.xlabel('Geração')

    plt.ylabel('Aptidão')

    plt.title('Evolução da Aptidão ao Longo das Gerações')

    plt.legend()

    plt.grid(True)

    plt.show()



# Função para plotar gráficos de barras dos totais de atributos

def plot_attribute_totals(generation_totals, attribute_name):

    generations = list(range(len(generation_totals)))

    plt.figure(figsize=(10, 6))

    plt.bar(generations, generation_totals)

    plt.xlabel('Geração')

    plt.ylabel(f'Total de {attribute_name}')

    plt.title(f'Variação do Total de {attribute_name} ao Longo das Gerações')

    plt.grid(True)

    plt.show()



if __name__ == '__main__':

    population = generate_random_population(population_size)

    best_fitness_values = []

    mean_fitness_values = []

    max_fitness = 250

    generation_reached_max_fitness = None



    # Inicializa listas para armazenar totais dos atributos

    total_ficha_limpa_list = []

    total_educacao_list = []

    total_experiencia_list = []

    total_transparencia_list = []

    total_popularidade_list = []



    for generation in range(num_generations):

        population = sorted(population, key=calculate_fitness, reverse=True)

        best_fitness = calculate_fitness(population[0])

        mean_fitness = np.mean([calculate_fitness(deputado) for deputado in population])

        best_fitness_values.append(best_fitness)

        mean_fitness_values.append(mean_fitness)



        # Acumula os totais dos atributos para a geração atual

        total_ficha_limpa = sum([deputado.ficha_limpa for deputado in population])


        total_educacao = sum([deputado.educacao for deputado in population])


        total_experiencia = sum([deputado.experiencia for deputado in population])

        total_transparencia = sum([deputado.transparencia for deputado in population])


        total_popularidade = sum([deputado.popularidade for deputado in population])



        total_ficha_limpa_list.append(total_ficha_limpa)

        total_educacao_list.append(total_educacao)

        total_experiencia_list.append(total_experiencia)

        total_transparencia_list.append(total_transparencia)

        total_popularidade_list.append(total_popularidade)

        if best_fitness >= max_fitness and generation_reached_max_fitness is None:

            generation_reached_max_fitness = generation

            print(f"Aptidão máxima atingida na geração {generation}")



        # Seleção dos pais (elitismo)

        parents = population[:population_size // 2]



        # Criação de nova geração

        new_population = []

        for _ in range(population_size // 2):

            parent1 = random.choice(parents)

            parent2 = random.choice(parents)

            child1, child2 = crossover(parent1, parent2)



            # Mutação

            if random.random() < mutation_rate:

                child1 = mutate(child1)

            if random.random() < mutation_rate:

                child2 = mutate(child2)



            new_population.extend([child1, child2])



        population = new_population



    # Imprime o melhor deputado encontrado

    best_deputado = population[0]

    print("\nMelhor Deputado Encontrado:")

    print(best_deputado)



    # Plota a evolução da aptidão

    plot_evolution(best_fitness_values, mean_fitness_values, generation_reached_max_fitness)



    # Plota gráficos de barras para os totais dos atributos

    plot_attribute_totals(total_ficha_limpa_list, 'Ficha Limpa')

    plot_attribute_totals(total_educacao_list, 'Educação')

    plot_attribute_totals(total_experiencia_list, 'Experiência')

    plot_attribute_totals(total_transparencia_list, 'Transparência')

    plot_attribute_totals(total_popularidade_list, 'Popularidade')



    # Imprime os totais dos atributos

    print("\nTotais dos Atributos desde a Geração Inicial até a Geração de Aptidão Máxima:")

    print(f"Total Ficha Limpa: {total_ficha_limpa}, Máximo Possivel: {513}")

    print(f"Total Educação: {total_educacao}, Máximo Possivel: {2565}")

    print(f"Total Experiência: {total_experiencia}, Máximo Possivel: {12825}")

    print(f"Total Transparência: {total_transparencia}, Máximo Possivel: {2565}")

    print(f"Total Popularidade: {total_popularidade}, Máximo Possivel: {51300}")
# Out:
# Aptidão máxima atingida na geração 2
#
# Melhor Deputado Encontrado:
# Deputado(Ficha Limpa: 1, Educação: 5, Experiência: 25, Transparência: 5, Popularidade: 100)
# Totais dos Atributos desde a Geração Inicial até a Geração de Aptidão Máxima:
# Total Ficha Limpa: 510, Máximo Possivel: 513
# Total Educação: 2556, Máximo Possivel: 2565
# Total Experiência: 12788, Máximo Possivel: 12825
# Total Transparência: 2555, Máximo Possivel: 2565
# Total Popularidade: 51160, Máximo Possivel: 51300
